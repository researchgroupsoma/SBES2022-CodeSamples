# %%
pip install pymannkendall
# Out:
# Collecting pymannkendall
#   Downloading https://files.pythonhosted.org/packages/c7/6b/64da7b1d0611ac3db668860a48978f0bd3db48bcda746474501f6b711183/pymannkendall-1.4.1-py3-none-any.whl
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from pymannkendall) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pymannkendall) (1.18.5)
# Installing collected packages: pymannkendall
# Successfully installed pymannkendall-1.4.1

# %%
import pandas as pd
import pymannkendall as mk

# %%
import os
os.chdir("/content/drive/My Drive/Faculdade/Mestrado/Pesquisa/Dados dos Samples/MannKendallTest/Todos Frameworks Juntos")

# %%
frame = pd.read_csv("todos_commits.csv")

# %%
frame
# Out:
#        numberOfJavaFiles  ...  readability
# 0                      0  ...     0.000000
# 1                      6  ...     0.000000
# 2                      0  ...     0.000000
# 3                      0  ...     0.000000
# 4                      0  ...     0.000000
# ...                  ...  ...          ...
# 28226                 27  ...     0.005426
# 28227                143  ...     0.020712
# 28228                 27  ...     0.005426
# 28229                143  ...     0.020712
# 28230                143  ...     0.020712
#
# [28231 rows x 4 columns]

# %%
mk.original_test(frame["numberOfJavaFiles"])
# Out:
# Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=48.81956771614167, Tau=0.19274725732232387, s=76806036.0, var_s=2475157462065.3335, slope=0.0002197963220748773, intercept=1.897574913913107)

# %%
mk.original_test(frame["countLineCode/numberOfJavaFiles"])
# Out:
# Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=40.58060555990536, Tau=0.1610100281804208, s=64159367.0, var_s=2499672317078.3335, slope=0.0009480190096279329, intercept=27.61871167910173)

# %%
mk.original_test(frame["SumCyclomaticStrict/CountDeclMethod"])
# Out:
# Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=31.71664321472194, Tau=0.12529353595952666, s=49927039.0, var_s=2477976421662.3335, slope=9.679340109574996e-06, intercept=1.2088306598078946)

# %%
mk.original_test(frame["readability"])
# Out:
# Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-32.995920997119505, Tau=-0.13009565472785353, s=-51840590.0, var_s=2468421635379.3335, slope=-1.3674029597745914e-07, intercept=0.03357670099796321)
