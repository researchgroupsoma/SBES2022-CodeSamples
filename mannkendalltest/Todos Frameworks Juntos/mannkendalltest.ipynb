# %%
pip install pymannkendall

# %%
import pandas as pd
import pymannkendall as mk

# %%
samplesAndroid = pd.read_csv("C:\\Users\\tati_\\Desktop\\gabriel\\pesquisamestrado-master\\pesquisamestrado-master\\listofsamples\\googlesamples.txt", sep="\n", header=None, names=["path"])

# %%
samplesAndroid
# Out:
#                                              path
# 0         googlesamples/android-AutofillFramework
# 1             googlesamples/android-play-location
# 2                   googlesamples/google-services
# 3                   googlesamples/easypermissions
# 4                   googlesamples/android-testing
# ..                                            ...
# 171    googlesamples/android-play-games-in-motion
# 172              googlesamples/androidtv-daydream
# 173  googlesamples/androidtv-VisualGameController
# 174        googlesamples/androidtv-GameController
# 175         googlesamples/android-google-accounts
#
# [176 rows x 1 columns]

# %%
samplesAWS = pd.read_csv("C:\\Users\\tati_\\Desktop\\gabriel\\pesquisamestrado-master\\pesquisamestrado-master\\listofsamples\\awssamples.txt", sep="\n", header=None, names=["path"])

# %%
samplesAWS
# Out:
#                                                   path
# 0              aws-samples/amazon-qldb-dmv-sample-java
# 1    aws-samples/amazon-chime-voiceconnector-transc...
# 2          aws-samples/aws-saas-factory-postgresql-rls
# 3          aws-samples/aws-greengrass-lambda-functions
# 4                                 aws-samples/djl-demo
# ..                                                 ...
# 106         aws-samples/aws-s3-artifact-manager-sample
# 107  aws-samples/aws-device-farm-sample-web-app-usi...
# 108  aws-samples/amazon-cognito-developer-authentic...
# 109                        aws-samples/emr-sample-apps
# 110            aws-samples/aws-dynamodb-mars-json-demo
#
# [111 rows x 1 columns]

# %%
samplesAzure = pd.read_csv("C:\\Users\\tati_\\Desktop\\gabriel\\pesquisamestrado-master\\pesquisamestrado-master\\listofsamples\\azuresamples.txt", sep="\n", header=None, names=["path"])

# %%
samplesAzure
# Out:
#                                                   path
# 0             Azure-Samples/Azure-Spring-Cloud-Samples
# 1    Azure-Samples/azure-cosmos-db-cassandra-java-g...
# 2      Azure-Samples/azure-iot-central-arm-sdk-samples
# 3    Azure-Samples/cognitive-services-personalizer-...
# 4              Azure-Samples/azure-search-java-samples
# ..                                                 ...
# 240  Azure-Samples/azure-mobile-apps-android-quicks...
# 241   Azure-Samples/storage-queue-java-getting-started
# 242  Azure-Samples/event-hubs-java-storm-sender-jms...
# 243  Azure-Samples/storage-java-client-side-encryption
# 244    Azure-Samples/storage-file-java-getting-started
#
# [245 rows x 1 columns]

# %%
samplesSpring = pd.read_csv("C:\\Users\\tati_\\Desktop\\gabriel\\pesquisamestrado-master\\pesquisamestrado-master\\listofsamples\\springsamples.txt", sep="\n", header=None, names=["path"])

# %%
samplesSpring
# Out:
#                                                  path
# 0                              spring-guides/tut-rest
# 1                       spring-guides/gs-vault-config
# 2                        spring-guides/gs-spring-boot
# 3                       spring-guides/gs-rest-service
# 4                 spring-guides/gs-spring-boot-docker
# 5                   spring-guides/gs-scheduling-tasks
# 6                              spring-guides/gs-maven
# 7                   spring-guides/gs-crud-with-vaadin
# 8                    spring-guides/gs-uploading-files
# 9                        spring-guides/gs-testing-web
# 10               spring-guides/gs-serving-web-content
# 11  spring-guides/gs-service-registration-and-disc...
# 12                      spring-guides/gs-securing-web
# 13                 spring-guides/gs-rest-service-cors
# 14            spring-guides/gs-relational-data-access
# 15             spring-guides/gs-producing-web-service
# ...

# %%
samplesAndroid["path"] = samplesAndroid["path"].str.replace("/", "\\\\")
samplesAWS["path"] = samplesAWS["path"].str.replace("/", "\\\\")
samplesAzure["path"] = samplesAzure["path"].str.replace("/", "\\\\")
samplesSpring["path"] = samplesSpring["path"].str.replace("/", "\\\\")

# %%
samples = pd.concat([samplesAndroid, samplesAWS, samplesAzure, samplesSpring], axis=0)
samples

# %%
samplesDataframe = [pd.read_csv("C:\\Users\\tati_\\Desktop\\gabriel\\pesquisamestrado-master\\pesquisamestrado-master\\metricsbycommits\\"+sample+"__output.csv", usecols=[3,4,5,6,7]) for sample in samples["path"]]

# %%
frame = pd.concat(samplesDataframe, axis=0, ignore_index=True)

# %%
frame.sort_values(by="date", inplace=True)

# %%
del frame["date"]

# %%
frame
# Out:
#        numberOfJavaFiles  countLineCode/numberOfJavaFiles  \
# 11662                  0                          0.00000
# 11663                  6                         79.50000
# 19529                  0                          0.00000
# 19530                  0                          0.00000
# 19531                  0                          0.00000
# ...                  ...                              ...
# 1620                  27                         95.37037
# 2864                 143                        135.20979
# 1621                  27                         95.37037
# 2865                 143                        135.20979
# 2866                 143                        135.20979
#
#        SumCyclomaticStrict/CountDeclMethod  readability
# 11662                             0.000000     0.000000
# 11663                             1.727273     0.000000
# 19529                             0.000000     0.000000
# ...

# %%
mk.original_test(frame["numberOfJavaFiles"])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-198-9fc0a60262e7> in <module>
# ----> 1 mk.original_test(frame["numberOfJavaFiles"])
#
# ~\anaconda3\lib\site-packages\pymannkendall\pymannkendall.py in original_test(x_old, alpha)
#     250     z = __z_score(s, var_s)
#     251     p, h, trend = __p_value(z, alpha)
# --> 252     slope, intercept = sens_slope(x_old)
#     253
#     254     return res(trend, h, p, z, Tau, s, var_s, slope, intercept)
#
# ~\anaconda3\lib\site-packages\pymannkendall\pymannkendall.py in sens_slope(x)
#     176 #     x, n = __missing_values_analysis(x, method = 'skip')
#     177     n = len(x)
# --> 178     slope = np.nanmedian(__sens_estimator(x))
#     179     intercept = np.nanmedian(x) - np.median(np.arange(n)[~np.isnan(x.flatten())]) * slope  # or median(x) - (n-1)/2 *slope
#     180
#
# ...

# %%
mk.original_test(frame["countLineCode/numberOfJavaFiles"])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-199-7ca5671bfbf9> in <module>
# ----> 1 mk.original_test(frame["countLineCode/numberOfJavaFiles"])
#
# ~\anaconda3\lib\site-packages\pymannkendall\pymannkendall.py in original_test(x_old, alpha)
#     250     z = __z_score(s, var_s)
#     251     p, h, trend = __p_value(z, alpha)
# --> 252     slope, intercept = sens_slope(x_old)
#     253
#     254     return res(trend, h, p, z, Tau, s, var_s, slope, intercept)
#
# ~\anaconda3\lib\site-packages\pymannkendall\pymannkendall.py in sens_slope(x)
#     176 #     x, n = __missing_values_analysis(x, method = 'skip')
#     177     n = len(x)
# --> 178     slope = np.nanmedian(__sens_estimator(x))
#     179     intercept = np.nanmedian(x) - np.median(np.arange(n)[~np.isnan(x.flatten())]) * slope  # or median(x) - (n-1)/2 *slope
#     180
#
# ...

# %%
mk.original_test(frame["SumCyclomaticStrict/CountDeclMethod"])

# %%
mk.original_test(frame["readability"])
