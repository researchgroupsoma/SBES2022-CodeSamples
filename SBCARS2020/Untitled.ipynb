# %%
import numpy as np
from scipy import stats
pts = 1000
np.random.seed(28041990)
import pandas as pd

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
abs(mu - np.mean(s))
abs(sigma - np.std(s, ddof=1))
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
from scipy import stats
stats.shapiro(s)
# Out:
# (0.9982545375823975, 0.4059831500053406)

# %%
pd.DataFrame(s).plot()

# %%
k2, p = stats.normaltest(s)
alpha = 0.05
print("p = {:g}".format(p))

if p < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis cannot be rejected")
# Out:
# p = 0.258666
# The null hypothesis cannot be rejected

# %%
l = []
for i in range(10000):
    l.append(i)

# %%
l[1] = 0
l[10] = 0
l[100] = 0
l[1000] = 0
l[2000] = 0
l[5000] = 0
l[8000] = 0

# %%
a = pd.DataFrame(l)

# %%
a.plot()

# %%
import pymannkendall as mk
result = mk.original_test(a)
result
# Out:
# Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=149.87717655064148, Tau=0.9993560556055605, s=49962806.0, var_s=111127774934.66667, slope=1.0, intercept=-2.0)

# %%
print(format(result.p, '.20f'))
# Out:
# 0.00000000000000976996
